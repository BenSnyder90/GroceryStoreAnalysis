# %%
import gmaps
import pandas as pd

# Google developer API key
from config import gkey

# Access maps with unique API key
gmaps.configure(api_key=gkey)

# %%
# Read in CSV with store data
store_map_df = pd.read_csv("total_store_data.csv", encoding = "utf-8" )

#Create lists of store coordinates to map
store_lats =  store_map_df['Lat'].tolist()
store_lngs = store_map_df['Lng'].tolist()
store_coords = list(zip(store_lats, store_lngs))
store_coords
# Out:
# [(41.26532359999999, -81.5074005),
#  (41.3169081, -81.81590340000002),
#  (41.5239553, -81.44661040000003),
#  (41.4605331, -82.0110016),
#  (41.11815720000001, -81.46922119999998),
#  (41.1331752, -81.6331853),
#  (40.87817379999999, -81.43716429999998),
#  (41.3664126, -81.5123818),
#  (41.42028, -81.757481),
#  (41.4218436, -82.0815143),
#  (41.7172108, -81.29339519999998),
#  (41.03433, -80.6336),
#  (41.115934, -81.4825905),
#  (40.8816904, -81.43993619999998),
#  (41.4419517, -81.4969558),
#  (41.376131, -81.786051),
#  (41.4632057, -82.0500783),
#  (41.63104209999999, -81.42605470000002),
#  (41.500618300000006, -81.53286990000002),
#  (41.6291084, -81.42994689999998),
#  (41.6862469, -81.29393519999998),
#  (41.35707670000001, -81.3863411),
#  (41.0404088, -81.69072969999998),
#  (41.4202263, -81.8953054),
#  (41.1209557, -81.4773818),
#  (41.1547186, -81.8654215),
#  (41.4578848, -81.68915340000002),
#  (40.8621536, -81.4314481),
#  (41.1280448, -81.60522979999998),
# ...

# %%
# Create custom marker and map figure
coords_layer = gmaps.symbol_layer(store_coords, 
        fill_color='green', stroke_color='green', scale=2)
fig = gmaps.figure()
fig.add_layer(starbucks_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…
