# %%
import requests
import json
import gmaps
from pprint import pprint
import pandas as pd
from api_keys import g_key

# %%
g_key = ''

# %%
clev_id = "41.4993,-81.6944"
target_type = "grocery_or_supermarket"

radius = 50000
search_wm = "Walmart in Ohio"
search_ge = "Giant Eagle in Ohio"
search_al = "Aldi's in Ohio"
search_wf = "Whole Foods Market in Ohio"
search_mr = "Marc's in Ohio"
search_sa = "Save A Lot in Ohio"
search_da = "Dave's Super Market in Ohio"
search_hn = "Heinen's in Ohio"

circle_one = "41.135466,-81.652035"
circle_two = "41.625126,-81.062346"
circle_three = "41.037209,-80.888368"

wm_keyword = "Walmart"
ge_keyword = "Giant Eagle"
al_keyword = "Aldi's"
wf_keyword = "Whole Foods Market"
mr_keyword = "Marc's"
sa_keyword = "Save A Lot"
da_keyword = "Dave's Super Market"
hn_keyword = "Heinen's"

lat = []
lng = []
name = []
address = []
place_id = []

params = {
    "location" : circle_one,
    "radius": radius,
    "key" : g_key,
    "keyword" : wm_keyword
}

url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response = requests.get(url,params)
walmart_one = response.json()

for index in walmart_one['results']:
    print(f"Adding Index {index['name']} from circle one for Walmart to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])

params = {
    "location" : circle_two,
    "radius": radius,
    "key" : g_key,
    "keyword" : wm_keyword
}

response = requests.get(url,params)
walmart_two = response.json()
for index in walmart_two['results']:
    print(f"Adding Index {index['name']} from circle two for Walmart to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
   
params = {
    "location" : circle_three,
    "radius": 32186,
    "key" : g_key,
    "keyword" : wm_keyword
}
response = requests.get(url,params)
walmart_three = response.json()
for index in walmart_three['results']:
    print(f"Adding Index {index['name']} from circle three for CostCo to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
# Out:
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle one for Walmart to the list...
# Adding Index Walmart from circle one for Walmart to the list...
# Adding Index Walmart Supercenter from circle two for Walmart to the list...
# Adding Index Walmart Supercenter from circle two for Walmart to the list...
# Adding Index Walmart Supercenter from circle two for Walmart to the list...
# Adding Index Walmart Supercenter from circle two for Walmart to the list...
# Adding Index Walmart from circle two for Walmart to the list...
# Adding Index Walmart Supercenter from circle two for Walmart to the list...
# Adding Index Walmart Supercenter from circle two for Walmart to the list...
# Adding Index Walmart Supercenter from circle two for Walmart to the list...
# Adding Index Walmart Supercenter from circle two for Walmart to the list...
# Adding Index Walmart from circle two for Walmart to the list...
# Adding Index Walmart Supercenter from circle two for Walmart to the list...
# Adding Index Walmart Supercenter from circle two for Walmart to the list...
# Adding Index Walmart Connection Center from circle two for Walmart to the list...
# Adding Index Walmart Money Center from circle two for Walmart to the list...
# Adding Index Walmart Pharmacy from circle two for Walmart to the list...
# Adding Index Walmart Connection Center from circle two for Walmart to the list...
# Adding Index Walmart Pharmacy from circle two for Walmart to the list...
# Adding Index Walmart Pharmacy from circle two for Walmart to the list...
# Adding Index Walmart Pharmacy from circle two for Walmart to the list...
# Adding Index Walmart Pharmacy from circle two for Walmart to the list...
# Adding Index Walmart Supercenter from circle three for CostCo to the list...
# Adding Index Walmart Supercenter from circle three for CostCo to the list...
# Adding Index Walmart Supercenter from circle three for CostCo to the list...
# Adding Index Walmart Supercenter from circle three for CostCo to the list...
# Adding Index Walmart Supercenter from circle three for CostCo to the list...
# Adding Index Walmart Supercenter from circle three for CostCo to the list...
# Adding Index Walmart Connection Center from circle three for CostCo to the list...
# Adding Index Walmart Money Center from circle three for CostCo to the list...
# Adding Index Walmart Photo Center from circle three for CostCo to the list...
# Adding Index Walmart Pharmacy from circle three for CostCo to the list...
# Adding Index Walmart Pharmacy from circle three for CostCo to the list...
# Adding Index Walmart Pharmacy from circle three for CostCo to the list...
# Adding Index Walmart Pharmacy from circle three for CostCo to the list...
# Adding Index Walmart Pharmacy from circle three for CostCo to the list...
# Adding Index Walmart Photo Center from circle three for CostCo to the list...
# Adding Index Walmart Photo Center from circle three for CostCo to the list...
# Adding Index ATM Wal-mart from circle three for CostCo to the list...
# Adding Index Walmart Photo Center from circle three for CostCo to the list...
# Adding Index Walmart Photo Center from circle three for CostCo to the list...

# %%
params = {
    "location" : circle_one,
    "radius": radius,
    "key" : g_key,
    "keyword" : ge_keyword
}
response = requests.get(url,params)
gianteagle_one = response.json()
for index in gianteagle_one['results']:
    print(f"Adding Index {index['name']} from circle one for Giant Eagle to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
   

params = {
    "location" : circle_two,
        "radius": radius,
    "key" : g_key,
    "keyword" : ge_keyword
}
response = requests.get(url,params)
gianteagle_two = response.json()
for index in gianteagle_two['results']:
    print(f"Adding Index {index['name']} from circle two for Giant Eagle to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])

    params = {
    "location" : circle_three,
    "radius": 32186,
    "key" : g_key,
    "keyword" : ge_keyword
}
response = requests.get(url,params)
gianteagle_three = response.json()

for index in gianteagle_three['results']:
    print(f"Adding Index {index['name']} from circle three for Giant Eagle to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
# Out:
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Market District from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Pharmacy from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Deli from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Deli from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Bakery from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle one for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle two for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Supermarket from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Deli from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Bakery from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Deli from circle three for Giant Eagle to the list...
# Adding Index Giant Eagle Deli from circle three for Giant Eagle to the list...

# %%
params = {
    "location" : circle_one,
    "radius": radius,
    "key" : g_key,
    "keyword" : al_keyword
}

#response = requests.get(url,params)

response = requests.get(url,params)
aldi_one = response.json()
for index in aldi_one['results']:
    print(f"Adding Index {index['name']}  from circle one for Aldi's to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])

params = {
    "location" : circle_two,
    "radius": radius,
    "key" : g_key,
    "keyword" : al_keyword
}
response = requests.get(url,params)
aldi_two = response.json()

for index in aldi_two['results']:
    print(f"Adding Index {index['name']} from circle two for Aldi's to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
    
params = {
    "location" : circle_three,
   
    "radius": 32186,
    "key" : g_key,
    "keyword" : al_keyword
}
response = requests.get(url,params)
aldi_three = response.json()

for index in aldi_three['results']:
    print(f"Adding Index {index['name']} from circle three for Aldi's to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
# Out:
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI  from circle one for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle two for Aldi's to the list...
# Adding Index ALDI from circle three for Aldi's to the list...
# Adding Index ALDI from circle three for Aldi's to the list...
# Adding Index ALDI from circle three for Aldi's to the list...
# Adding Index ALDI from circle three for Aldi's to the list...
# Adding Index ALDI from circle three for Aldi's to the list...
# Adding Index ALDI from circle three for Aldi's to the list...
# Adding Index ALDI from circle three for Aldi's to the list...
# Adding Index ALDI from circle three for Aldi's to the list...
# Adding Index ALDI from circle three for Aldi's to the list...

# %%
params = {
    "location" : circle_one,
    "radius": radius,
    "key" : g_key,
    "keyword" : wf_keyword
}


response = requests.get(url,params)
wf_one = response.json()
for index in wf_one['results']:
    print(f"Adding Index {index['name']}  from circle one for Whole Foods Market to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])

params = {
    "location" : circle_two,
    "radius": radius,
    "key" : g_key,
    "keyword" : wf_keyword
}
response = requests.get(url,params)
wf_two = response.json()

for index in wf_two['results']:
    print(f"Adding Index {index['name']} from circle two for Whole Foods Market to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
    
params = {
    "location" : circle_three,
   
    "radius": 32186,
    "key" : g_key,
    "keyword" : wf_keyword
}
response = requests.get(url,params)
wf_three = response.json()

for index in wf_three['results']:
    print(f"Adding Index {index['name']} from circle three for Whole Foods Market to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
# Out:
# Adding Index Whole Foods Market 365  from circle one for Whole Foods Market to the list...
# Adding Index Whole Foods Market  from circle one for Whole Foods Market to the list...
# Adding Index Whole Foods Market  from circle one for Whole Foods Market to the list...
# Adding Index Whole Foods Market  from circle one for Whole Foods Market to the list...
# Adding Index Whole Foods Market from circle two for Whole Foods Market to the list...
# Adding Index Whole Foods Market from circle two for Whole Foods Market to the list...
# Adding Index Whole Foods Market from circle two for Whole Foods Market to the list...
# Adding Index Berry's Natural Food Market from circle three for Whole Foods Market to the list...

# %%
params = {
    "location" : circle_one,
    "radius": radius,
    "key" : g_key,
    "keyword" : mr_keyword
}
response = requests.get(url,params)
mr_one = response.json()
for index in mr_one['results']:
    print(f"Adding Index {index['name']}  from circle one for Marc's to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])

params = {
    "location" : circle_two,
    "radius": radius,
    "key" : g_key,
    "keyword" : mr_keyword
}
response = requests.get(url,params)
mr_two = response.json()

for index in mr_two['results']:
    print(f"Adding Index {index['name']} from circle two for Marc's to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
    
params = {
    "location" : circle_three,
    
    "radius": 32186,
    "key" : g_key,
    "keyword" : mr_keyword
}
response = requests.get(url,params)
mr_three = response.json()

for index in mr_three['results']:
    print(f"Adding Index {index['name']} from circle three for Marc's to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
# Out:
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Pharmacy  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores  from circle one for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Pharmacy from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle two for Marc's to the list...
# Adding Index Marc's Pharmacy from circle two for Marc's to the list...
# Adding Index Marc's Pharmacy from circle two for Marc's to the list...
# Adding Index Marc's Stores from circle three for Marc's to the list...
# Adding Index Marc's Stores from circle three for Marc's to the list...
# Adding Index Marc's Stores from circle three for Marc's to the list...
# Adding Index Marc's Stores from circle three for Marc's to the list...
# Adding Index Marc's Stores from circle three for Marc's to the list...
# Adding Index Marc's Stores from circle three for Marc's to the list...
# Adding Index Marc's Pharmacy from circle three for Marc's to the list...
# Adding Index Marc's Pharmacy from circle three for Marc's to the list...
# Adding Index Marc's Pharmacy from circle three for Marc's to the list...

# %%
params = {
    "location" : circle_one,
    
    "radius": radius,
    "key" : g_key,
    "keyword" : sa_keyword
}
response = requests.get(url,params)
sa_one = response.json()

for index in sa_one['results']:
    print(f"Adding Index {index['name']}  from circle one for Save A Lot to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
    
params = {
    "location" : circle_two,
    "radius": radius,
    "key" : g_key,
    "keyword" : sa_keyword
}
response = requests.get(url,params)
sa_two = response.json()

for index in sa_two['results']:
    print(f"Adding Index {index['name']} from circle two for Save A Lot to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
   
params = {
    "location" : circle_three,
  
    "radius": 32186,
    "key" : g_key,
    "keyword" : sa_keyword
}
response = requests.get(url,params)
sa_three = response.json()
for index in sa_three['results']:
    print(f"Adding Index {index['name']} from circle three for Save A Lot to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
# Out:
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot  from circle one for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle two for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...
# Adding Index Save A Lot from circle three for Save A Lot to the list...

# %%
params = {
    "location" : circle_one,
    
    "radius": radius,
    "key" : g_key,
    "keyword" : da_keyword
}
response = requests.get(url,params)
da_one = response.json()

for index in da_one['results']:
    print(f"Adding Index {index['name']}  from circle one for Dave's Super Market to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
    
params = {
    "location" : circle_two,
    "radius": radius,
    "key" : g_key,
    "keyword" : da_keyword
}
response = requests.get(url,params)
da_two = response.json()

for index in da_two['results']:
    print(f"Adding Index {index['name']} from circle two for Dave's Super Market to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
   
params = {
    "location" : circle_three,
  
    "radius": 32186,
    "key" : g_key,
    "keyword" : da_keyword
}
response = requests.get(url,params)
da_three = response.json()
for index in da_three['results']:
    print(f"Adding Index {index['name']} from circle three for Dave's Super Market to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
# Out:
# Adding Index Dave's Markets Middlebury Market  from circle one for Dave's Super Market to the list...
# Adding Index Dave's Supermarket  from circle one for Dave's Super Market to the list...
# Adding Index Dave's Markets Ohio City  from circle one for Dave's Super Market to the list...
# Adding Index Dave's Mercado  from circle one for Dave's Super Market to the list...
# Adding Index Dave's Markets Slavic Village  from circle one for Dave's Super Market to the list...
# Adding Index Dave's Markets Turneytown  from circle one for Dave's Super Market to the list...
# Adding Index Dave's Markets Harvard & Lee  from circle one for Dave's Super Market to the list...
# Adding Index Dave's Markets Corporate Headquarters  from circle one for Dave's Super Market to the list...
# Adding Index Dave's Markets Wilson Mills  from circle one for Dave's Super Market to the list...
# Adding Index Dave's Markets Cedar Hill  from circle one for Dave's Super Market to the list...
# Adding Index Dave's Markets Severance  from circle one for Dave's Super Market to the list...
# Adding Index Dave's  from circle one for Dave's Super Market to the list...
# Adding Index Dave's Markets Euclid Beach  from circle one for Dave's Super Market to the list...
# Adding Index Dave's Supermarket from circle two for Dave's Super Market to the list...
# Adding Index Dave's Markets Shore Center from circle two for Dave's Super Market to the list...
# Adding Index Dave's Markets Wilson Mills from circle two for Dave's Super Market to the list...
# Adding Index Dave's Markets Turneytown from circle two for Dave's Super Market to the list...
# Adding Index Dave's Markets Severance from circle two for Dave's Super Market to the list...
# Adding Index Dave's Markets Euclid Beach from circle two for Dave's Super Market to the list...
# Adding Index Dave's Markets Slavic Village from circle two for Dave's Super Market to the list...
# Adding Index Dave's Markets Corporate Headquarters from circle two for Dave's Super Market to the list...
# Adding Index Dave's Markets Cedar Hill from circle two for Dave's Super Market to the list...
# Adding Index Dave's Markets Harvard & Lee from circle two for Dave's Super Market to the list...
# Adding Index Dave's Market & eatery from circle two for Dave's Super Market to the list...

# %%
params = {
    "location" : circle_one,
    
    "radius": radius,
    "key" : g_key,
    "keyword" : hn_keyword
}
response = requests.get(url,params)
hn_one = response.json()

for index in hn_one['results']:
    print(f"Adding Index {index['name']}  from circle one for Heinen's to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
    
params = {
    "location" : circle_two,
    "radius": radius,
    "key" : g_key,
    "keyword" : hn_keyword
}
response = requests.get(url,params)
hn_two = response.json()

for index in hn_two['results']:
    print(f"Adding Index {index['name']} from circle two for Heinen's to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
   
params = {
    "location" : circle_three,
  
    "radius": 32186,
    "key" : g_key,
    "keyword" : hn_keyword
}
response = requests.get(url,params)
hn_three = response.json()
for index in hn_three['results']:
    print(f"Adding Index {index['name']} from circle three for Heinen's to the list...")
    name.append(index['name'])
    lat.append(index['geometry']['location']['lat'])
    lng.append(index['geometry']['location']['lng'])
    address.append(index['vicinity'])
    place_id.append(index['place_id'])
# Out:
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index The Tasting Room Bistro at Heinen's of Chagrin Falls  from circle one for Heinen's to the list...
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index Heinen's of Downtown Cleveland  from circle one for Heinen's to the list...
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index Heinen's Grocery Store  from circle one for Heinen's to the list...
# Adding Index Heinen's - Corporate Office  from circle one for Heinen's to the list...
# Adding Index Heinen's, Inc. - Warehouse  from circle one for Heinen's to the list...
# Adding Index Heinen's grocery  from circle one for Heinen's to the list...
# Adding Index The Tasting Room Bistro at Heinen's of Chagrin Falls from circle two for Heinen's to the list...
# Adding Index Heinen's Grocery Store from circle two for Heinen's to the list...
# Adding Index Heinen's Grocery Store from circle two for Heinen's to the list...
# Adding Index Heinen's Grocery Store from circle two for Heinen's to the list...
# Adding Index Heinen's Grocery Store from circle two for Heinen's to the list...
# Adding Index Heinen's Grocery Store from circle two for Heinen's to the list...
# Adding Index Heinen's Grocery Store from circle two for Heinen's to the list...
# Adding Index Heinen's Grocery Store from circle two for Heinen's to the list...
# Adding Index Heinen's Grocery Store from circle two for Heinen's to the list...
# Adding Index Heinen's Grocery Store from circle two for Heinen's to the list...
# Adding Index Heinen's Grocery Store from circle two for Heinen's to the list...
# Adding Index Heinen's Grocery Store from circle two for Heinen's to the list...
# Adding Index Heinen's Grocery Store from circle two for Heinen's to the list...
# Adding Index Heinen's Grocery Store from circle two for Heinen's to the list...
# Adding Index Heinen's - Corporate Office from circle two for Heinen's to the list...
# Adding Index Heinen's, Inc. - Warehouse from circle two for Heinen's to the list...

# %%
store_list = pd.DataFrame(data = {"Name":name,"Lat":lat,"Lng":lng,"Address":address,"Place ID":place_id})
store_list
# Out:
#                             Name        Lat        Lng  \
# 0            Walmart Supercenter  41.165890 -81.480013
# 1            Walmart Supercenter  41.098492 -81.384385
# 2                        Walmart  41.135370 -81.632149
# 3            Walmart Supercenter  40.993039 -81.489007
# 4            Walmart Supercenter  41.156854 -81.299629
# ..                           ...        ...        ...
# 336       Heinen's Grocery Store  41.588116 -81.218803
# 337       Heinen's Grocery Store  41.606722 -81.442266
# 338       Heinen's Grocery Store  41.672846 -81.323319
# 339  Heinen's - Corporate Office  41.437493 -81.502472
# 340   Heinen's, Inc. - Warehouse  41.427141 -81.535691
#
#                                     Address                     Place ID
# 0                      3520 Hudson Dr, Stow  ChIJZ-vS1KknMYgRFeF3mAX3Wcs
# 1                    250 Tallmadge Rd, Kent  ChIJ_4OGF58vMYgR1MZBZf907h0
# 2                3750 W Market St, Fairlawn  ChIJecKBe5zQMIgRb4r9N1FH1DQ
# 3                2887 S Arlington Rd, Akron  ChIJkS50luwqMYgRj9C384PYJEc
# 4                       2600 OH-59, Ravenna  ChIJdV72JQc7MYgR1d6qv2TxUpE
# ..                                      ...                          ...
# 336                  402 Center St, Chardon  ChIJ1QMvToOgMYgRsd-40CDvvWA
# 337              34501 Ridge Rd, Willoughby  ChIJz34dxQ6qMYgRad3XD53J_KA
# 338                 8850 Mentor Ave, Mentor  ChIJMeVS0uOlMYgRJ6pIM5WtpH8
# 339  4540 Richmond Rd, Warrensville Heights  ChIJ68VTnU8dMYgRL7RjEccj0SQ
# 340                20601 Aurora Rd, Oakwood  ChIJBZRnrJDiMIgRKE25n_-tAUM
#
# [341 rows x 5 columns]

# %%
#Make sure duplicates exist of Lat and Lng and are mutually exclusive
print(store_list['Lat'].value_counts().value_counts())
print(store_list['Lng'].value_counts().value_counts())
# Out:
# 1    221
# 2     60
# Name: Lat, dtype: int64
# 1    221
# 2     60
# Name: Lng, dtype: int64

# %%
#Drop the duplicate entries from Lat and Lng
dropped_store_list = store_list.drop_duplicates(subset = ['Lat','Lng']).reset_index(drop=True)

#Check to see if there are duplicates with address
print(dropped_store_list['Address'].value_counts().value_counts())

#Drop duplicate addresses and verify
dropped_store_list = dropped_store_list.drop_duplicates(subset = "Address").reset_index(drop=True)
print(dropped_store_list['Address'].value_counts().value_counts())
#store_list.to_csv("output_data/store_data.csv",index=False,header=True)

#Drop extra column of indexes
dropped_store_list = dropped_store_list[["Name","Lat","Lng","Address","Place ID"]]
dropped_store_list.head()
# Out:
# 1    228
# 2     17
# 3      5
# 4      1
# Name: Address, dtype: int64
# 1    251
# Name: Address, dtype: int64

# %%
county_url = f"https://maps.googleapis.com/maps/api/place/details/json?key={g_key}&place_id="
county = []

#Test to find the right field
    #p_id = "ChIJrwEsWXIgMYgRnko93meT4s0"
    #response = requests.get(county_url+p_id).json()
    #pprint(response['result']['address_components'][3]['long_name'])

#Use place details API to get the county name from the place ID
for x in dropped_store_list['Place ID']:
    response = requests.get(county_url+x).json()
    county.append(response['result']['address_components'][3]['long_name'])

dropped_store_list["County"] = county
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-b62505791c0d> in <module>
#      13
#      14 dropped_store_list["County"] = county
# ---> 15 dropped(store_list)
#
# NameError: name 'dropped' is not defined

# %%
dropped_store_list = pd.read_csv("store_data_NEO_places.csv")
#dropped_store_list = dropped_store_list.drop(dropped_store_list.columns[0],axis=1)
dropped_store_list = dropped_store_list[["Name","Lat","Lng","Address","Place ID","County"]]
print(dropped_store_list.columns)

dropped_store_list.to_csv("store_data_NEO_places.csv",index=False,header=True)
# Out:
# Index(['Name', 'Lat', 'Lng', 'Address', 'Place ID', 'County'], dtype='object')
