# %%
# Dependencies
import numpy as np
import pandas as pd
import requests
from census import Census
import gmaps
import json
from pprint import pprint
import re

# Census & gmaps API Keys
from config import (api_key, gkey)
c = Census(api_key, year=2018)

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# Run Census Search to retrieve data on all states
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E",
                          "B19301_001E", "B17001_002E",), {'for': 'state:39'})


#{'for': 'state:39'}) = OHIO

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "state": "State"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rate"] = 100 * \
    census_pd["Poverty Count"].astype(
        int) / census_pd["Population"].astype(int)


# Final DataFrame
census_pd = census_pd[["State", "Name", "Population", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate",]]

census_pd.head()
# Out:
#   State  Name  Population  Household Income  Per Capita Income  Poverty Count  \
# 0    39  Ohio  11641879.0           54533.0            30304.0      1645986.0
#
#    Poverty Rate
# 0     14.138491

# %%
#c.sf1.get('NAME', geo={'for': 'tract:*',
#                       'in': 'state:{} county:170'.format(states.AK.fips)})

census_data_new = c.acs5.get(("NAME", "B19013_001E", "B01003_001E",
                          "B19301_001E", "B17001_002E",),geo={'for':'county:*', 'in':'state:39'})

census_data_new
# Out:
# [{'NAME': 'Gallia County, Ohio',
#   'B19013_001E': 42113.0,
#   'B01003_001E': 30195.0,
#   'B19301_001E': 22588.0,
#   'B17001_002E': 6608.0,
#   'state': '39',
#   'county': '053'},
#  {'NAME': 'Huron County, Ohio',
#   'B19013_001E': 51559.0,
#   'B01003_001E': 58457.0,
#   'B19301_001E': 25375.0,
#   'B17001_002E': 7845.0,
#   'state': '39',
#   'county': '077'},
#  {'NAME': 'Athens County, Ohio',
#   'B19013_001E': 37778.0,
#   'B01003_001E': 65936.0,
#   'B19301_001E': 20745.0,
#   'B17001_002E': 17212.0,
#   'state': '39',
#   'county': '009'},
#  {'NAME': 'Adams County, Ohio',
#   'B19013_001E': 36894.0,
#   'B01003_001E': 27878.0,
#   'B19301_001E': 21543.0,
#   'B17001_002E': 6230.0,
#   'state': '39',
#   'county': '001'},
#  {'NAME': 'Medina County, Ohio',
#   'B19013_001E': 74243.0,
#   'B01003_001E': 177257.0,
#   'B19301_001E': 35979.0,
#   'B17001_002E': 11303.0,
#   'state': '39',
#   'county': '103'},
#  {'NAME': 'Union County, Ohio',
#   'B19013_001E': 82775.0,
#   'B01003_001E': 55654.0,
#   'B19301_001E': 34691.0,
#   'B17001_002E': 3610.0,
#   'state': '39',
#   'county': '159'},
#  {'NAME': 'Champaign County, Ohio',
#   'B19013_001E': 57103.0,
#   'B01003_001E': 38864.0,
#   'B19301_001E': 26515.0,
#   'B17001_002E': 4180.0,
#   'state': '39',
#   'county': '021'},
#  {'NAME': 'Paulding County, Ohio',
#   'B19013_001E': 51933.0,
#   'B01003_001E': 18872.0,
#   'B19301_001E': 25918.0,
#   'B17001_002E': 1919.0,
#   'state': '39',
#   'county': '125'},
#  {'NAME': 'Greene County, Ohio',
#   'B19013_001E': 67109.0,
#   'B01003_001E': 165811.0,
#   'B19301_001E': 34682.0,
#   'B17001_002E': 19065.0,
#   'state': '39',
#   'county': '057'},
#  {'NAME': 'Franklin County, Ohio',
#   'B19013_001E': 58762.0,
#   'B01003_001E': 1275333.0,
#   'B19301_001E': 32552.0,
#   'B17001_002E': 203044.0,
#   'state': '39',
#   'county': '049'},
#  {'NAME': 'Marion County, Ohio',
#   'B19013_001E': 45464.0,
#   'B01003_001E': 65344.0,
#   'B19301_001E': 22878.0,
#   'B17001_002E': 9504.0,
#   'state': '39',
#   'county': '101'},
#  {'NAME': 'Morgan County, Ohio',
#   'B19013_001E': 41731.0,
#   'B01003_001E': 14702.0,
#   'B19301_001E': 22454.0,
#   'B17001_002E': 2765.0,
#   'state': '39',
#   'county': '115'},
#  {'NAME': 'Wayne County, Ohio',
#   'B19013_001E': 56348.0,
#   'B01003_001E': 116208.0,
#   'B19301_001E': 26822.0,
#   'B17001_002E': 13885.0,
#   'state': '39',
#   'county': '169'},
#  {'NAME': 'Wyandot County, Ohio',
#   'B19013_001E': 52940.0,
#   'B01003_001E': 22107.0,
#   'B19301_001E': 27037.0,
#   'B17001_002E': 2068.0,
#   'state': '39',
#   'county': '175'},
#  {'NAME': 'Butler County, Ohio',
#   'B19013_001E': 63358.0,
#   'B01003_001E': 378294.0,
#   'B19301_001E': 30777.0,
#   'B17001_002E': 47601.0,
#   'state': '39',
#   'county': '017'},
#  {'NAME': 'Harrison County, Ohio',
#   'B19013_001E': 48462.0,
#   'B01003_001E': 15307.0,
#   'B19301_001E': 24108.0,
#   'B17001_002E': 2545.0,
#   'state': '39',
#   'county': '067'},
#  {'NAME': 'Knox County, Ohio',
#   'B19013_001E': 55131.0,
#   'B01003_001E': 61215.0,
#   'B19301_001E': 25589.0,
#   'B17001_002E': 8222.0,
#   'state': '39',
#   'county': '083'},
#  {'NAME': 'Richland County, Ohio',
#   'B19013_001E': 47346.0,
#   'B01003_001E': 121324.0,
#   'B19301_001E': 24545.0,
#   'B17001_002E': 16190.0,
#   'state': '39',
#   'county': '139'},
#  {'NAME': 'Vinton County, Ohio',
#   'B19013_001E': 42114.0,
#   'B01003_001E': 13111.0,
#   'B19301_001E': 20823.0,
#   'B17001_002E': 2719.0,
#   'state': '39',
#   'county': '163'},
#  {'NAME': 'Hancock County, Ohio',
#   'B19013_001E': 55644.0,
#   'B01003_001E': 75690.0,
#   'B19301_001E': 30794.0,
#   'B17001_002E': 8545.0,
#   'state': '39',
#   'county': '063'},
#  {'NAME': 'Fairfield County, Ohio',
#   'B19013_001E': 66175.0,
#   'B01003_001E': 152910.0,
#   'B19301_001E': 31136.0,
#   'B17001_002E': 14142.0,
#   'state': '39',
#   'county': '045'},
#  {'NAME': 'Defiance County, Ohio',
#   'B19013_001E': 57665.0,
#   'B01003_001E': 38279.0,
#   'B19301_001E': 28491.0,
#   'B17001_002E': 4032.0,
#   'state': '39',
#   'county': '039'},
#  {'NAME': 'Henry County, Ohio',
#   'B19013_001E': 59083.0,
#   'B01003_001E': 27316.0,
#   'B19301_001E': 28328.0,
#   'B17001_002E': 2593.0,
#   'state': '39',
#   'county': '069'},
#  {'NAME': 'Jefferson County, Ohio',
#   'B19013_001E': 44819.0,
#   'B01003_001E': 66886.0,
#   'B19301_001E': 25658.0,
#   'B17001_002E': 11647.0,
#   'state': '39',
#   'county': '081'},
#  {'NAME': 'Putnam County, Ohio',
#   'B19013_001E': 62001.0,
#   'B01003_001E': 33969.0,
#   'B19301_001E': 30064.0,
#   'B17001_002E': 2265.0,
#   'state': '39',
#   'county': '137'},
#  {'NAME': 'Clinton County, Ohio',
#   'B19013_001E': 51354.0,
#   'B01003_001E': 41896.0,
#   'B19301_001E': 26861.0,
#   'B17001_002E': 5277.0,
#   'state': '39',
#   'county': '027'},
#  {'NAME': 'Fayette County, Ohio',
#   'B19013_001E': 46478.0,
#   'B01003_001E': 28645.0,
#   'B19301_001E': 24931.0,
#   'B17001_002E': 4764.0,
#   'state': '39',
#   'county': '047'},
#  {'NAME': 'Pickaway County, Ohio',
#   'B19013_001E': 62214.0,
#   'B01003_001E': 57420.0,
#   'B19301_001E': 26515.0,
#   'B17001_002E': 6174.0,
#   'state': '39',
#   'county': '129'},
#  {'NAME': 'Logan County, Ohio',
#   'B19013_001E': 55150.0,
#   'B01003_001E': 45307.0,
#   'B19301_001E': 27840.0,
#   'B17001_002E': 5984.0,
#   'state': '39',
#   'county': '091'},
#  {'NAME': 'Summit County, Ohio',
#   'B19013_001E': 55448.0,
#   'B01003_001E': 541810.0,
#   'B19301_001E': 32055.0,
#   'B17001_002E': 69576.0,
#   'state': '39',
#   'county': '153'},
#  {'NAME': 'Sandusky County, Ohio',
#   'B19013_001E': 51701.0,
#   'B01003_001E': 59299.0,
#   'B19301_001E': 26256.0,
#   'B17001_002E': 7872.0,
#   'state': '39',
#   'county': '143'},
#  {'NAME': 'Shelby County, Ohio',
#   'B19013_001E': 61042.0,
#   'B01003_001E': 48797.0,
#   'B19301_001E': 29008.0,
#   'B17001_002E': 4384.0,
#   'state': '39',
#   'county': '149'},
#  {'NAME': 'Van Wert County, Ohio',
#   'B19013_001E': 52754.0,
#   'B01003_001E': 28281.0,
#   'B19301_001E': 26698.0,
#   'B17001_002E': 3100.0,
#   'state': '39',
#   'county': '161'},
#  {'NAME': 'Washington County, Ohio',
#   'B19013_001E': 48572.0,
#   'B01003_001E': 60671.0,
#   'B19301_001E': 27860.0,
#   'B17001_002E': 8921.0,
#   'state': '39',
#   'county': '167'},
#  {'NAME': 'Williams County, Ohio',
#   'B19013_001E': 49491.0,
#   'B01003_001E': 36936.0,
#   'B19301_001E': 25428.0,
#   'B17001_002E': 4886.0,
#   'state': '39',
#   'county': '171'},
#  {'NAME': 'Auglaize County, Ohio',
#   'B19013_001E': 61758.0,
#   'B01003_001E': 45784.0,
#   'B19301_001E': 29908.0,
#   'B17001_002E': 3906.0,
#   'state': '39',
#   'county': '011'},
#  {'NAME': 'Columbiana County, Ohio',
#   'B19013_001E': 46306.0,
#   'B01003_001E': 104003.0,
#   'B19301_001E': 25853.0,
#   'B17001_002E': 14639.0,
#   'state': '39',
#   'county': '029'},
#  {'NAME': 'Darke County, Ohio',
#   'B19013_001E': 52691.0,
#   'B01003_001E': 51734.0,
#   'B19301_001E': 26262.0,
#   'B17001_002E': 5124.0,
#   'state': '39',
#   'county': '037'},
#  {'NAME': 'Ottawa County, Ohio',
#   'B19013_001E': 57918.0,
#   'B01003_001E': 40709.0,
#   'B19301_001E': 33081.0,
#   'B17001_002E': 4181.0,
#   'state': '39',
#   'county': '123'},
#  {'NAME': 'Fulton County, Ohio',
#   'B19013_001E': 60231.0,
#   'B01003_001E': 42305.0,
#   'B19301_001E': 28411.0,
#   'B17001_002E': 3919.0,
#   'state': '39',
#   'county': '051'},
#  {'NAME': 'Hardin County, Ohio',
#   'B19013_001E': 48773.0,
#   'B01003_001E': 31542.0,
#   'B19301_001E': 22329.0,
#   'B17001_002E': 4880.0,
#   'state': '39',
#   'county': '065'},
#  {'NAME': 'Jackson County, Ohio',
#   'B19013_001E': 45340.0,
#   'B01003_001E': 32524.0,
#   'B19301_001E': 22117.0,
#   'B17001_002E': 6265.0,
#   'state': '39',
#   'county': '079'},
#  {'NAME': 'Lucas County, Ohio',
#   'B19013_001E': 46924.0,
#   'B01003_001E': 432379.0,
#   'B19301_001E': 28361.0,
#   'B17001_002E': 80686.0,
#   'state': '39',
#   'county': '095'},
#  {'NAME': 'Morrow County, Ohio',
#   'B19013_001E': 56010.0,
#   'B01003_001E': 34976.0,
#   'B19301_001E': 27212.0,
#   'B17001_002E': 3524.0,
#   'state': '39',
#   'county': '117'},
#  {'NAME': 'Noble County, Ohio',
#   'B19013_001E': 47456.0,
#   'B01003_001E': 14443.0,
#   'B19301_001E': 24616.0,
#   'B17001_002E': 1835.0,
#   'state': '39',
#   'county': '121'},
#  {'NAME': 'Preble County, Ohio',
#   'B19013_001E': 55374.0,
#   'B01003_001E': 41207.0,
#   'B19301_001E': 27031.0,
#   'B17001_002E': 4683.0,
#   'state': '39',
#   'county': '135'},
#  {'NAME': 'Seneca County, Ohio',
#   'B19013_001E': 49936.0,
#   'B01003_001E': 55475.0,
#   'B19301_001E': 25555.0,
#   'B17001_002E': 7680.0,
#   'state': '39',
#   'county': '147'},
#  {'NAME': 'Stark County, Ohio',
#   'B19013_001E': 52190.0,
#   'B01003_001E': 373475.0,
#   'B19301_001E': 28434.0,
#   'B17001_002E': 50408.0,
#   'state': '39',
#   'county': '151'},
#  {'NAME': 'Allen County, Ohio',
#   'B19013_001E': 50552.0,
#   'B01003_001E': 103642.0,
#   'B19301_001E': 25662.0,
#   'B17001_002E': 14795.0,
#   'state': '39',
#   'county': '003'},
#  {'NAME': 'Coshocton County, Ohio',
#   'B19013_001E': 44491.0,
#   'B01003_001E': 36574.0,
#   'B19301_001E': 22471.0,
#   'B17001_002E': 5899.0,
#   'state': '39',
#   'county': '031'},
#  {'NAME': 'Crawford County, Ohio',
#   'B19013_001E': 42892.0,
#   'B01003_001E': 42021.0,
#   'B19301_001E': 24513.0,
#   'B17001_002E': 6182.0,
#   'state': '39',
#   'county': '033'},
#  {'NAME': 'Delaware County, Ohio',
#   'B19013_001E': 104322.0,
#   'B01003_001E': 197008.0,
#   'B19301_001E': 47183.0,
#   'B17001_002E': 8843.0,
#   'state': '39',
#   'county': '041'},
#  {'NAME': 'Guernsey County, Ohio',
#   'B19013_001E': 43975.0,
#   'B01003_001E': 39274.0,
#   'B19301_001E': 23599.0,
#   'B17001_002E': 7815.0,
#   'state': '39',
#   'county': '059'},
#  {'NAME': 'Hocking County, Ohio',
#   'B19013_001E': 50000.0,
#   'B01003_001E': 28495.0,
#   'B19301_001E': 24138.0,
#   'B17001_002E': 3785.0,
#   'state': '39',
#   'county': '073'},
#  {'NAME': 'Mercer County, Ohio',
#   'B19013_001E': 59417.0,
#   'B01003_001E': 40806.0,
#   'B19301_001E': 28513.0,
#   'B17001_002E': 2788.0,
#   'state': '39',
#   'county': '107'},
#  {'NAME': 'Ross County, Ohio',
#   'B19013_001E': 48403.0,
#   'B01003_001E': 77051.0,
#   'B19301_001E': 23756.0,
#   'B17001_002E': 12694.0,
#   'state': '39',
#   'county': '141'},
#  {'NAME': 'Cuyahoga County, Ohio',
#   'B19013_001E': 48435.0,
#   'B01003_001E': 1253783.0,
#   'B19301_001E': 31804.0,
#   'B17001_002E': 221899.0,
#   'state': '39',
#   'county': '035'},
#  {'NAME': 'Lorain County, Ohio',
#   'B19013_001E': 56965.0,
#   'B01003_001E': 306713.0,
#   'B19301_001E': 29777.0,
#   'B17001_002E': 40799.0,
#   'state': '39',
#   'county': '093'},
#  {'NAME': 'Miami County, Ohio',
#   'B19013_001E': 57544.0,
#   'B01003_001E': 104800.0,
#   'B19301_001E': 29703.0,
#   'B17001_002E': 9764.0,
#   'state': '39',
#   'county': '109'},
#  {'NAME': 'Montgomery County, Ohio',
#   'B19013_001E': 49314.0,
#   'B01003_001E': 532034.0,
#   'B19301_001E': 28807.0,
#   'B17001_002E': 89854.0,
#   'state': '39',
#   'county': '113'},
#  {'NAME': 'Trumbull County, Ohio',
#   'B19013_001E': 45975.0,
#   'B01003_001E': 201794.0,
#   'B19301_001E': 26116.0,
#   'B17001_002E': 34604.0,
#   'state': '39',
#   'county': '155'},
#  {'NAME': 'Wood County, Ohio',
#   'B19013_001E': 59789.0,
#   'B01003_001E': 129936.0,
#   'B19301_001E': 31324.0,
#   'B17001_002E': 16365.0,
#   'state': '39',
#   'county': '173'},
#  {'NAME': 'Ashtabula County, Ohio',
#   'B19013_001E': 44823.0,
#   'B01003_001E': 98136.0,
#   'B19301_001E': 22817.0,
#   'B17001_002E': 19216.0,
#   'state': '39',
#   'county': '007'},
#  {'NAME': 'Madison County, Ohio',
#   'B19013_001E': 65264.0,
#   'B01003_001E': 43988.0,
#   'B19301_001E': 28331.0,
#   'B17001_002E': 3939.0,
#   'state': '39',
#   'county': '097'},
#  {'NAME': 'Muskingum County, Ohio',
#   'B19013_001E': 45276.0,
#   'B01003_001E': 86076.0,
#   'B19301_001E': 24080.0,
#   'B17001_002E': 13669.0,
#   'state': '39',
#   'county': '119'},
#  {'NAME': 'Geauga County, Ohio',
#   'B19013_001E': 79956.0,
#   'B01003_001E': 93961.0,
#   'B19301_001E': 42149.0,
#   'B17001_002E': 5642.0,
#   'state': '39',
#   'county': '055'},
#  {'NAME': 'Monroe County, Ohio',
#   'B19013_001E': 43956.0,
#   'B01003_001E': 14090.0,
#   'B19301_001E': 25141.0,
#   'B17001_002E': 2309.0,
#   'state': '39',
#   'county': '111'},
#  {'NAME': 'Lake County, Ohio',
#   'B19013_001E': 63475.0,
#   'B01003_001E': 230052.0,
#   'B19301_001E': 33737.0,
#   'B17001_002E': 18830.0,
#   'state': '39',
#   'county': '085'},
#  {'NAME': 'Clark County, Ohio',
#   'B19013_001E': 48502.0,
#   'B01003_001E': 135198.0,
#   'B19301_001E': 25948.0,
#   'B17001_002E': 20775.0,
#   'state': '39',
#   'county': '023'},
#  {'NAME': 'Holmes County, Ohio',
#   'B19013_001E': 62111.0,
#   'B01003_001E': 43859.0,
#   'B19301_001E': 22923.0,
#   'B17001_002E': 4787.0,
#   'state': '39',
#   'county': '075'},
#  {'NAME': 'Warren County, Ohio',
#   'B19013_001E': 83330.0,
#   'B01003_001E': 226564.0,
#   'B19301_001E': 39448.0,
#   'B17001_002E': 10100.0,
#   'state': '39',
#   'county': '165'},
#  {'NAME': 'Ashland County, Ohio',
#   'B19013_001E': 52730.0,
#   'B01003_001E': 53477.0,
#   'B19301_001E': 25471.0,
#   'B17001_002E': 6769.0,
#   'state': '39',
#   'county': '005'},
#  {'NAME': 'Mahoning County, Ohio',
#   'B19013_001E': 44682.0,
#   'B01003_001E': 231064.0,
#   'B19301_001E': 27429.0,
#   'B17001_002E': 39441.0,
#   'state': '39',
#   'county': '099'},
#  {'NAME': 'Scioto County, Ohio',
#   'B19013_001E': 39731.0,
#   'B01003_001E': 76377.0,
#   'B19301_001E': 23042.0,
#   'B17001_002E': 17132.0,
#   'state': '39',
#   'county': '145'},
#  {'NAME': 'Meigs County, Ohio',
#   'B19013_001E': 43591.0,
#   'B01003_001E': 23160.0,
#   'B19301_001E': 23897.0,
#   'B17001_002E': 5130.0,
#   'state': '39',
#   'county': '105'},
#  {'NAME': 'Pike County, Ohio',
#   'B19013_001E': 43729.0,
#   'B01003_001E': 28214.0,
#   'B19301_001E': 22301.0,
#   'B17001_002E': 5395.0,
#   'state': '39',
#   'county': '131'},
#  {'NAME': 'Hamilton County, Ohio',
#   'B19013_001E': 54976.0,
#   'B01003_001E': 812037.0,
#   'B19301_001E': 34125.0,
#   'B17001_002E': 128930.0,
#   'state': '39',
#   'county': '061'},
#  {'NAME': 'Erie County, Ohio',
#   'B19013_001E': 52270.0,
#   'B01003_001E': 75136.0,
#   'B19301_001E': 31677.0,
#   'B17001_002E': 8858.0,
#   'state': '39',
#   'county': '043'},
#  {'NAME': 'Lawrence County, Ohio',
#   'B19013_001E': 44372.0,
#   'B01003_001E': 60622.0,
#   'B19301_001E': 23692.0,
#   'B17001_002E': 11082.0,
#   'state': '39',
#   'county': '087'},
#  {'NAME': 'Tuscarawas County, Ohio',
#   'B19013_001E': 51170.0,
#   'B01003_001E': 92526.0,
#   'B19301_001E': 26034.0,
#   'B17001_002E': 11990.0,
#   'state': '39',
#   'county': '157'},
#  {'NAME': 'Brown County, Ohio',
#   'B19013_001E': 52356.0,
#   'B01003_001E': 43679.0,
#   'B19301_001E': 25637.0,
#   'B17001_002E': 6818.0,
#   'state': '39',
#   'county': '015'},
#  {'NAME': 'Licking County, Ohio',
#   'B19013_001E': 62715.0,
#   'B01003_001E': 172293.0,
#   'B19301_001E': 30338.0,
#   'B17001_002E': 19101.0,
#   'state': '39',
#   'county': '089'},
#  {'NAME': 'Carroll County, Ohio',
#   'B19013_001E': 52394.0,
#   'B01003_001E': 27578.0,
#   'B19301_001E': 28421.0,
#   'B17001_002E': 3549.0,
#   'state': '39',
#   'county': '019'},
#  {'NAME': 'Clermont County, Ohio',
#   'B19013_001E': 64822.0,
#   'B01003_001E': 203216.0,
#   'B19301_001E': 32900.0,
#   'B17001_002E': 19204.0,
#   'state': '39',
#   'county': '025'},
#  {'NAME': 'Highland County, Ohio',
#   'B19013_001E': 43297.0,
#   'B01003_001E': 43007.0,
#   'B19301_001E': 22624.0,
#   'B17001_002E': 8836.0,
#   'state': '39',
#   'county': '071'},
#  {'NAME': 'Portage County, Ohio',
#   'B19013_001E': 56618.0,
#   'B01003_001E': 162644.0,
#   'B19301_001E': 29439.0,
#   'B17001_002E': 20346.0,
#   'state': '39',
#   'county': '133'},
#  {'NAME': 'Belmont County, Ohio',
#   'B19013_001E': 49361.0,
#   'B01003_001E': 68472.0,
#   'B19301_001E': 26106.0,
#   'B17001_002E': 8738.0,
#   'state': '39',
#   'county': '013'},
#  {'NAME': 'Perry County, Ohio',
#   'B19013_001E': 48811.0,
#   'B01003_001E': 35985.0,
#   'B19301_001E': 22659.0,
#   'B17001_002E': 6907.0,
#   'state': '39',
#   'county': '127'}]

# %%
censusnew_pd = pd.DataFrame(census_data_new)

# Column Reordering
censusnew_pd = censusnew_pd.rename(columns={"B01003_001E": "Population",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "state": "State", "county" : "County"})
censusnew_pd["Poverty Rate"] = 100 * \
    censusnew_pd["Poverty Count"].astype(
        int) / censusnew_pd["Population"].astype(int)

# Final DataFrame
censusnew_pd = censusnew_pd[["Name", "Population", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate",]]

censusnew_pd["Population"] = censusnew_pd["Population"].map("{:,.0f}".format)
censusnew_pd["Household Income"] = censusnew_pd["Household Income"].map("${:20,.0f}".format)
censusnew_pd["Per Capita Income"] = censusnew_pd["Per Capita Income"].map("${:20,.0f}".format)
censusnew_pd["Poverty Count"] = censusnew_pd["Poverty Count"].map("{:,.0f}".format)
censusnew_pd["Poverty Rate"] = censusnew_pd["Poverty Rate"].map("{:.2f}%".format)

#    censusnew_pd['Name'] = censusnew_pd['Name'].map(lambda x: x.rstrip(', Ohio'))



censusnew_pd.head()
# Out:
#                   Name Population       Household Income  \
# 0  Gallia County, Ohio     30,195  $              42,113
# 1   Huron County, Ohio     58,457  $              51,559
# 2  Athens County, Ohio     65,936  $              37,778
# 3   Adams County, Ohio     27,878  $              36,894
# 4  Medina County, Ohio    177,257  $              74,243
#
#        Per Capita Income Poverty Count Poverty Rate
# 0  $              22,588         6,608       21.88%
# 1  $              25,375         7,845       13.42%
# 2  $              20,745        17,212       26.10%
# 3  $              21,543         6,230       22.35%
# 4  $              35,979        11,303        6.38%

# %%
censusnew_pd['Name'] = censusnew_pd['Name'].map(lambda x: x.rstrip(', Ohio'))
censusnew_pd.head(80)
# Out:
#                  Name Population       Household Income  \
# 0       Gallia County     30,195  $              42,113
# 1        Huron County     58,457  $              51,559
# 2       Athens County     65,936  $              37,778
# 3        Adams County     27,878  $              36,894
# 4       Medina County    177,257  $              74,243
# ..                ...        ...                    ...
# 75        Pike County     28,214  $              43,729
# 76    Hamilton County    812,037  $              54,976
# 77        Erie County     75,136  $              52,270
# 78    Lawrence County     60,622  $              44,372
# 79  Tuscarawas County     92,526  $              51,170
#
#         Per Capita Income Poverty Count Poverty Rate
# 0   $              22,588         6,608       21.88%
# 1   $              25,375         7,845       13.42%
# 2   $              20,745        17,212       26.10%
# 3   $              21,543         6,230       22.35%
# 4   $              35,979        11,303        6.38%
# ..                    ...           ...          ...
# 75  $              22,301         5,395       19.12%
# 76  $              34,125       128,930       15.88%
# 77  $              31,677         8,858       11.79%
# 78  $              23,692        11,082       18.28%
# 79  $              26,034        11,990       12.96%
#
# [80 rows x 6 columns]

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
census_pd.to_csv("Output_CSVs/census_data_states.csv", encoding="utf-8", index=False)
censusnew_pd.to_csv("Output_CSVs/census_data_counties.csv", encoding="utf-8", index=False)
